# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>
# <p style="font-size:36px;text-align:center"> <b>Assignment : Apply All models using TfidfVectorizer with top 1000 words using idf score</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
#from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# <h2>Reading Data</h2>

# %% [markdown]
# <h3>Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('/content/drive/My Drive/training_variants.zip')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3> Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("/content/drive/My Drive/training_text.zip",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>Preprocessing of text</h3>

# %%
# loading stop words from nltk library
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 279.087429 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 226
# BRCA1     162
# TP53      109
# EGFR       94
# BRCA2      84
# PTEN       83
# KIT        70
# BRAF       64
# ERBB2      45
# ALK        42
# PDGFRA     39
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 226 different categories of genes in the train data, and they are distibuted as follows

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2019    MAP2K1
# 228       EGFR
# 2957      GNAS
# 1749      MSH2
# 1488     FGFR2
# Name: Gene, dtype: object

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 226)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1961)

# %%
# building a TfidfVectorizer with all the words that occured minimum 5 times in train data
text_vectorizer = TfidfVectorizer(min_df=5,max_features=1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-6, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42,n_jobs=-1)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42,n_jobs=-1)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-06 The log loss is: 1.2524085999435148
# For values of alpha =  1e-05 The log loss is: 1.1817025340250011
# For values of alpha =  0.0001 The log loss is: 1.1860767558931256
# For values of alpha =  0.001 The log loss is: 1.4920370550151876
# For values of alpha =  0.01 The log loss is: 1.9015250530564525
# For values of alpha =  0.1 The log loss is: 2.0139659328958706
# For values of alpha =  1 The log loss is: 1.9986932674252487
# For values of best alpha =  1e-05 The train log loss is: 0.7558339665179256
# For values of best alpha =  1e-05 The cross validation log loss is: 1.1817025340250011
# For values of best alpha =  1e-05 The test log loss is: 1.1277066233125683

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(min_df=50,max_features=2000)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 48.1 % of word of test data appeared in train data
# 47.75 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer()
    var_count_vec = TfidfVectorizer()
    text_count_vec = TfidfVectorizer(min_df=5,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 3187)
# (number of data points * number of features) in test data =  (665, 3187)
# (number of data points * number of features) in cross validation data = (532, 3187)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000,1200,1300]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2189348708333472
# for alpha = 0.0001
# Log Loss : 1.2182887523220776
# for alpha = 0.001
# Log Loss : 1.2173416431732078
# for alpha = 0.1
# Log Loss : 1.2609537600556586
# for alpha = 1
# Log Loss : 1.3402339421830987
# for alpha = 10
# Log Loss : 1.5263104366354354
# for alpha = 100
# Log Loss : 1.4986838781594076
# for alpha = 1000
# Log Loss : 1.4861485310708693
# for alpha = 1200
# Log Loss : 1.4859415363867965
# for alpha = 1300
# Log Loss : 1.4858622580255447
# For values of best alpha =  0.001 The train log loss is: 0.50414463395501
# For values of best alpha =  0.001 The cross validation log loss is: 1.2173416431732078
# For values of best alpha =  0.001 The test log loss is: 1.2057639951258043

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.2173416431732078
# Number of missclassified point : 0.40037593984962405
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0756 0.0486 0.0127 0.6468 0.0763 0.0482 0.0855 0.0033 0.003 ]]
# Actual Class : 4
# --------------------------------------------------
# 8 Text feature [activity] present in test data point [True]
# 9 Text feature [protein] present in test data point [True]
# 13 Text feature [proteins] present in test data point [True]
# 14 Text feature [experiments] present in test data point [True]
# 16 Text feature [function] present in test data point [True]
# 17 Text feature [results] present in test data point [True]
# 18 Text feature [shown] present in test data point [True]
# 19 Text feature [type] present in test data point [True]
# 20 Text feature [whether] present in test data point [True]
# 22 Text feature [also] present in test data point [True]
# 23 Text feature [whereas] present in test data point [True]
# 24 Text feature [described] present in test data point [True]
# 25 Text feature [acid] present in test data point [True]
# 26 Text feature [wild] present in test data point [True]
# 27 Text feature [missense] present in test data point [True]
# 28 Text feature [suppressor] present in test data point [True]
# 29 Text feature [determined] present in test data point [True]
# 30 Text feature [amino] present in test data point [True]
# 31 Text feature [important] present in test data point [True]
# 32 Text feature [two] present in test data point [True]
# 33 Text feature [reduced] present in test data point [True]
# 34 Text feature [may] present in test data point [True]
# 37 Text feature [related] present in test data point [True]
# 38 Text feature [mutations] present in test data point [True]
# 39 Text feature [either] present in test data point [True]
# 41 Text feature [functional] present in test data point [True]
# 43 Text feature [discussion] present in test data point [True]
# 44 Text feature [three] present in test data point [True]
# 46 Text feature [although] present in test data point [True]
# 47 Text feature [levels] present in test data point [True]
# 48 Text feature [loss] present in test data point [True]
# 49 Text feature [catalytic] present in test data point [True]
# 50 Text feature [previously] present in test data point [True]
# 51 Text feature [30] present in test data point [True]
# 52 Text feature [tagged] present in test data point [True]
# 53 Text feature [thus] present in test data point [True]
# 54 Text feature [containing] present in test data point [True]
# 60 Text feature [bind] present in test data point [True]
# 61 Text feature [similar] present in test data point [True]
# 62 Text feature [could] present in test data point [True]
# 63 Text feature [therefore] present in test data point [True]
# 64 Text feature [show] present in test data point [True]
# 65 Text feature [buffer] present in test data point [True]
# 67 Text feature [however] present in test data point [True]
# 68 Text feature [ability] present in test data point [True]
# 69 Text feature [analysis] present in test data point [True]
# 72 Text feature [effect] present in test data point [True]
# 73 Text feature [binding] present in test data point [True]
# 74 Text feature [associated] present in test data point [True]
# 75 Text feature [expressed] present in test data point [True]
# 76 Text feature [10] present in test data point [True]
# 77 Text feature [cells] present in test data point [True]
# 78 Text feature [several] present in test data point [True]
# 79 Text feature [suggested] present in test data point [True]
# 81 Text feature [using] present in test data point [True]
# 82 Text feature [one] present in test data point [True]
# 83 Text feature [mutant] present in test data point [True]
# 85 Text feature [mm] present in test data point [True]
# 87 Text feature [result] present in test data point [True]
# 88 Text feature [used] present in test data point [True]
# 89 Text feature [possible] present in test data point [True]
# 90 Text feature [mutants] present in test data point [True]
# 91 Text feature [transfected] present in test data point [True]
# 92 Text feature [fact] present in test data point [True]
# 93 Text feature [addition] present in test data point [True]
# 94 Text feature [affect] present in test data point [True]
# 95 Text feature [found] present in test data point [True]
# 96 Text feature [site] present in test data point [True]
# 97 Text feature [functions] present in test data point [True]
# 98 Text feature [introduction] present in test data point [True]
# 99 Text feature [general] present in test data point [True]
# Out of the top  100  features  71 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 20
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0596 0.0969 0.0125 0.0634 0.0346 0.0471 0.6795 0.0034 0.003 ]]
# Actual Class : 2
# --------------------------------------------------
# 15 Text feature [activation] present in test data point [True]
# 17 Text feature [kinase] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 20 Text feature [inhibitor] present in test data point [True]
# 21 Text feature [cells] present in test data point [True]
# 22 Text feature [signaling] present in test data point [True]
# 23 Text feature [expressing] present in test data point [True]
# 24 Text feature [independent] present in test data point [True]
# 25 Text feature [growth] present in test data point [True]
# 26 Text feature [also] present in test data point [True]
# 27 Text feature [inhibition] present in test data point [True]
# 28 Text feature [factor] present in test data point [True]
# 29 Text feature [contrast] present in test data point [True]
# 30 Text feature [presence] present in test data point [True]
# 31 Text feature [treatment] present in test data point [True]
# 33 Text feature [10] present in test data point [True]
# 35 Text feature [addition] present in test data point [True]
# 36 Text feature [however] present in test data point [True]
# 37 Text feature [mutations] present in test data point [True]
# 38 Text feature [cell] present in test data point [True]
# 39 Text feature [well] present in test data point [True]
# 40 Text feature [inhibitors] present in test data point [True]
# 41 Text feature [may] present in test data point [True]
# 42 Text feature [activating] present in test data point [True]
# 43 Text feature [higher] present in test data point [True]
# 44 Text feature [found] present in test data point [True]
# 45 Text feature [previously] present in test data point [True]
# 46 Text feature [treated] present in test data point [True]
# 47 Text feature [shown] present in test data point [True]
# 48 Text feature [similar] present in test data point [True]
# 49 Text feature [oncogenic] present in test data point [True]
# 50 Text feature [compared] present in test data point [True]
# 51 Text feature [recently] present in test data point [True]
# 52 Text feature [potential] present in test data point [True]
# 53 Text feature [tyrosine] present in test data point [True]
# 54 Text feature [3b] present in test data point [True]
# 55 Text feature [phosphorylation] present in test data point [True]
# 56 Text feature [increased] present in test data point [True]
# 57 Text feature [pathway] present in test data point [True]
# 59 Text feature [showed] present in test data point [True]
# 62 Text feature [receptor] present in test data point [True]
# 63 Text feature [although] present in test data point [True]
# 64 Text feature [therapeutic] present in test data point [True]
# 65 Text feature [pathways] present in test data point [True]
# 67 Text feature [reported] present in test data point [True]
# 68 Text feature [survival] present in test data point [True]
# 69 Text feature [suggest] present in test data point [True]
# 70 Text feature [mutation] present in test data point [True]
# 71 Text feature [described] present in test data point [True]
# 73 Text feature [3a] present in test data point [True]
# 75 Text feature [results] present in test data point [True]
# 76 Text feature [studies] present in test data point [True]
# 77 Text feature [proliferation] present in test data point [True]
# 78 Text feature [15] present in test data point [True]
# 79 Text feature [clinical] present in test data point [True]
# 80 Text feature [observed] present in test data point [True]
# 81 Text feature [absence] present in test data point [True]
# 83 Text feature [fig] present in test data point [True]
# 85 Text feature [12] present in test data point [True]
# 86 Text feature [enhanced] present in test data point [True]
# 87 Text feature [different] present in test data point [True]
# 88 Text feature [identified] present in test data point [True]
# 89 Text feature [20] present in test data point [True]
# 90 Text feature [mechanism] present in test data point [True]
# 91 Text feature [demonstrated] present in test data point [True]
# 92 Text feature [serum] present in test data point [True]
# 93 Text feature [high] present in test data point [True]
# 95 Text feature [induced] present in test data point [True]
# 96 Text feature [mutant] present in test data point [True]
# 98 Text feature [either] present in test data point [True]
# Out of the top  100  features  70 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [3, 5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i,n_jobs=-1)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha],n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 3
# Log Loss : 1.126395550115388
# for alpha = 5
# Log Loss : 1.1350571365789237
# for alpha = 11
# Log Loss : 1.1722000172151088
# for alpha = 15
# Log Loss : 1.1864845388243546
# for alpha = 21
# Log Loss : 1.2005875956726968
# for alpha = 31
# Log Loss : 1.217110606369633
# for alpha = 41
# Log Loss : 1.2396180416278872
# for alpha = 51
# Log Loss : 1.261290423435938
# for alpha = 99
# Log Loss : 1.315457095160189
# For values of best alpha =  3 The train log loss is: 0.8108803300598406
# For values of best alpha =  3 The cross validation log loss is: 1.126395550115388
# For values of best alpha =  3 The test log loss is: 1.0761216104094211

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha],n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.126395550115388
# Number of mis-classified points : 0.35902255639097747
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha],n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_onehotCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_onehotCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 4
# The  3  nearest neighbours of the test points belongs to classes [5 4 5]
# Fequency of nearest points : Counter({5: 2, 4: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha],n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_onehotCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 3 and the nearest neighbours of the test points belongs to classes [7 7 7]
# Fequency of nearest points : Counter({7: 3})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [0.00001,0.0001,0.0002,0.0003,0.001,0.002,0.01,0.02,0.1,0.2,0.3]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42,n_jobs=-1)
    clf.fit(train_x_onehotCoding, train_y)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    #sig_clf.fit(train_gene_var_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    #sig_clf_probs = sig_clf.predict_proba(cv_gene_var_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42,n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
#clf.fit(train_gene_var_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
#sig_clf.fit(train_gene_var_onehotCoding, train_y)
predict_y = sig_clf.predict_proba(train_x_onehotCoding)
#predict_y = sig_clf.predict_proba(train_gene_var_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
#predict_y = sig_clf.predict_proba(cv_gene_var_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
#predict_y = sig_clf.predict_proba(test_gene_var_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1281011416939681
# for alpha = 0.0001
# Log Loss : 1.0508057486290607
# for alpha = 0.0002
# Log Loss : 1.0501246704205218
# for alpha = 0.0003
# Log Loss : 1.0547325419072027
# for alpha = 0.001
# Log Loss : 1.0866811654062336
# for alpha = 0.002
# Log Loss : 1.1169323551954236
# for alpha = 0.01
# Log Loss : 1.2642829010534913
# for alpha = 0.02
# Log Loss : 1.3496200140697943
# for alpha = 0.1
# Log Loss : 1.660467062827381
# for alpha = 0.2
# Log Loss : 1.729191784719743
# for alpha = 0.3
# Log Loss : 1.7523658868992535
# For values of best alpha =  0.0002 The train log loss is: 0.5000470990972529
# For values of best alpha =  0.0002 The cross validation log loss is: 1.0501246704205218
# For values of best alpha =  0.0002 The test log loss is: 1.0077116689179197

# %% [markdown]
# **We have at last breached 1.0 log loss by achieving 0.92 log loss on test data**

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0501246704205218
# Number of mis-classified points : 0.35150375939849626
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0587 0.0711 0.0093 0.5551 0.1757 0.1036 0.0182 0.0046 0.0037]]
# Actual Class : 4
# --------------------------------------------------
# 12 Text feature [suppressor] present in test data point [True]
# 88 Text feature [lane] present in test data point [True]
# 91 Text feature [tagged] present in test data point [True]
# 98 Text feature [missense] present in test data point [True]
# 99 Text feature [dominant] present in test data point [True]
# 126 Text feature [mm] present in test data point [True]
# 148 Text feature [substrate] present in test data point [True]
# 154 Text feature [family] present in test data point [True]
# 161 Text feature [germline] present in test data point [True]
# 192 Text feature [transfected] present in test data point [True]
# 193 Text feature [protein] present in test data point [True]
# 202 Text feature [tumorigenesis] present in test data point [True]
# 206 Text feature [caused] present in test data point [True]
# 223 Text feature [washed] present in test data point [True]
# 235 Text feature [cycle] present in test data point [True]
# 247 Text feature [intermediate] present in test data point [True]
# 255 Text feature [show] present in test data point [True]
# 265 Text feature [heterozygous] present in test data point [True]
# 280 Text feature [changes] present in test data point [True]
# 282 Text feature [degradation] present in test data point [True]
# 287 Text feature [reduced] present in test data point [True]
# 303 Text feature [bind] present in test data point [True]
# 326 Text feature [buffer] present in test data point [True]
# 328 Text feature [ca] present in test data point [True]
# 336 Text feature [consequences] present in test data point [True]
# 337 Text feature [affected] present in test data point [True]
# 341 Text feature [catalytic] present in test data point [True]
# 378 Text feature [see] present in test data point [True]
# 391 Text feature [loss] present in test data point [True]
# 406 Text feature [shows] present in test data point [True]
# 409 Text feature [years] present in test data point [True]
# 412 Text feature [via] present in test data point [True]
# 415 Text feature [relatively] present in test data point [True]
# 424 Text feature [activity] present in test data point [True]
# 429 Text feature [specifically] present in test data point [True]
# 434 Text feature [free] present in test data point [True]
# 440 Text feature [incubated] present in test data point [True]
# 441 Text feature [anti] present in test data point [True]
# 442 Text feature [play] present in test data point [True]
# 445 Text feature [due] present in test data point [True]
# 452 Text feature [page] present in test data point [True]
# 462 Text feature [high] present in test data point [True]
# 464 Text feature [2a] present in test data point [True]
# 465 Text feature [seen] present in test data point [True]
# 467 Text feature [several] present in test data point [True]
# 469 Text feature [dna] present in test data point [True]
# 471 Text feature [sds] present in test data point [True]
# 473 Text feature [cbl] present in test data point [True]
# 482 Text feature [involved] present in test data point [True]
# 483 Text feature [plasmid] present in test data point [True]
# 485 Text feature [mouse] present in test data point [True]
# 486 Text feature [bound] present in test data point [True]
# 488 Text feature [functional] present in test data point [True]
# 489 Text feature [half] present in test data point [True]
# 494 Text feature [transfection] present in test data point [True]
# 496 Text feature [distribution] present in test data point [True]
# Out of the top  500  features  56 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 600
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[5.316e-01 7.400e-03 3.800e-03 4.303e-01 8.500e-03 5.600e-03 3.000e-03
#   9.500e-03 4.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 3 Text feature [hotspots] present in test data point [True]
# 6 Text feature [surface] present in test data point [True]
# 18 Text feature [hotspot] present in test data point [True]
# 24 Text feature [nucleus] present in test data point [True]
# 27 Text feature [deficient] present in test data point [True]
# 64 Text feature [transcriptional] present in test data point [True]
# 111 Text feature [brain] present in test data point [True]
# 112 Text feature [hydrophobic] present in test data point [True]
# 157 Text feature [functions] present in test data point [True]
# 160 Text feature [ability] present in test data point [True]
# 175 Text feature [encoding] present in test data point [True]
# 184 Text feature [panel] present in test data point [True]
# 187 Text feature [calculated] present in test data point [True]
# 189 Text feature [fraction] present in test data point [True]
# 194 Text feature [position] present in test data point [True]
# 201 Text feature [loss] present in test data point [True]
# 211 Text feature [function] present in test data point [True]
# 212 Text feature [defined] present in test data point [True]
# 222 Text feature [rather] present in test data point [True]
# 235 Text feature [structure] present in test data point [True]
# 242 Text feature [peptide] present in test data point [True]
# 248 Text feature [molecules] present in test data point [True]
# 252 Text feature [value] present in test data point [True]
# 259 Text feature [affect] present in test data point [True]
# 272 Text feature [nuclear] present in test data point [True]
# 276 Text feature [displayed] present in test data point [True]
# 280 Text feature [deletion] present in test data point [True]
# 283 Text feature [remaining] present in test data point [True]
# 285 Text feature [21] present in test data point [True]
# 287 Text feature [specificity] present in test data point [True]
# 289 Text feature [percentage] present in test data point [True]
# 290 Text feature [mutational] present in test data point [True]
# 291 Text feature [next] present in test data point [True]
# 301 Text feature [side] present in test data point [True]
# 310 Text feature [identify] present in test data point [True]
# 313 Text feature [moreover] present in test data point [True]
# 314 Text feature [essential] present in test data point [True]
# 318 Text feature [subjected] present in test data point [True]
# 327 Text feature [hydrogen] present in test data point [True]
# 328 Text feature [region] present in test data point [True]
# 333 Text feature [construct] present in test data point [True]
# 334 Text feature [normalized] present in test data point [True]
# 339 Text feature [page] present in test data point [True]
# 341 Text feature [individual] present in test data point [True]
# 344 Text feature [ref] present in test data point [True]
# 345 Text feature [transcription] present in test data point [True]
# 346 Text feature [crystal] present in test data point [True]
# 350 Text feature [early] present in test data point [True]
# 351 Text feature [vivo] present in test data point [True]
# 352 Text feature [activities] present in test data point [True]
# 353 Text feature [driven] present in test data point [True]
# 354 Text feature [strand] present in test data point [True]
# 355 Text feature [therefore] present in test data point [True]
# 356 Text feature [impact] present in test data point [True]
# 359 Text feature [signal] present in test data point [True]
# 360 Text feature [structural] present in test data point [True]
# 361 Text feature [primers] present in test data point [True]
# 362 Text feature [general] present in test data point [True]
# 364 Text feature [upon] present in test data point [True]
# 368 Text feature [1997] present in test data point [True]
# 372 Text feature [controls] present in test data point [True]
# 373 Text feature [author] present in test data point [True]
# 374 Text feature [population] present in test data point [True]
# 375 Text feature [complexes] present in test data point [True]
# 377 Text feature [sequenced] present in test data point [True]
# 378 Text feature [cohort] present in test data point [True]
# 381 Text feature [staining] present in test data point [True]
# 384 Text feature [chain] present in test data point [True]
# 385 Text feature [corresponding] present in test data point [True]
# 386 Text feature [carrying] present in test data point [True]
# 387 Text feature [1999] present in test data point [True]
# 388 Text feature [regulatory] present in test data point [True]
# 389 Text feature [somatic] present in test data point [True]
# 391 Text feature [assess] present in test data point [True]
# 392 Text feature [complex] present in test data point [True]
# 395 Text feature [positions] present in test data point [True]
# 397 Text feature [molecule] present in test data point [True]
# 398 Text feature [strong] present in test data point [True]
# 399 Text feature [length] present in test data point [True]
# 401 Text feature [reporter] present in test data point [True]
# 402 Text feature [less] present in test data point [True]
# 403 Text feature [rt] present in test data point [True]
# 404 Text feature [http] present in test data point [True]
# 406 Text feature [complete] present in test data point [True]
# 407 Text feature [human] present in test data point [True]
# 408 Text feature [sequences] present in test data point [True]
# 409 Text feature [defects] present in test data point [True]
# 414 Text feature [core] present in test data point [True]
# 416 Text feature [domains] present in test data point [True]
# 418 Text feature [whole] present in test data point [True]
# 419 Text feature [indicated] present in test data point [True]
# 420 Text feature [sds] present in test data point [True]
# 421 Text feature [allele] present in test data point [True]
# 422 Text feature [s1] present in test data point [True]
# 424 Text feature [stability] present in test data point [True]
# 427 Text feature [manufacturer] present in test data point [True]
# 428 Text feature [greater] present in test data point [True]
# 429 Text feature [change] present in test data point [True]
# 430 Text feature [nucleotide] present in test data point [True]
# 431 Text feature [sirna] present in test data point [True]
# 432 Text feature [established] present in test data point [True]
# 433 Text feature [sequencing] present in test data point [True]
# 434 Text feature [following] present in test data point [True]
# 435 Text feature [assays] present in test data point [True]
# 437 Text feature [repair] present in test data point [True]
# 438 Text feature [major] present in test data point [True]
# 439 Text feature [dependent] present in test data point [True]
# 440 Text feature [knockdown] present in test data point [True]
# 441 Text feature [fold] present in test data point [True]
# 442 Text feature [types] present in test data point [True]
# 443 Text feature [one] present in test data point [True]
# 444 Text feature [conserved] present in test data point [True]
# 445 Text feature [across] present in test data point [True]
# 446 Text feature [impaired] present in test data point [True]
# 448 Text feature [responses] present in test data point [True]
# 449 Text feature [vitro] present in test data point [True]
# 454 Text feature [37] present in test data point [True]
# 455 Text feature [1b] present in test data point [True]
# 456 Text feature [line] present in test data point [True]
# 457 Text feature [reduction] present in test data point [True]
# 458 Text feature [blood] present in test data point [True]
# 460 Text feature [screening] present in test data point [True]
# 461 Text feature [suppression] present in test data point [True]
# 463 Text feature [49] present in test data point [True]
# 464 Text feature [frequency] present in test data point [True]
# 465 Text feature [treated] present in test data point [True]
# 466 Text feature [possibility] present in test data point [True]
# 467 Text feature [17] present in test data point [True]
# 468 Text feature [colorectal] present in test data point [True]
# 469 Text feature [powerpoint] present in test data point [True]
# 470 Text feature [targeting] present in test data point [True]
# 471 Text feature [average] present in test data point [True]
# 472 Text feature [located] present in test data point [True]
# 473 Text feature [affecting] present in test data point [True]
# 474 Text feature [induce] present in test data point [True]
# 476 Text feature [protein] present in test data point [True]
# 477 Text feature [determined] present in test data point [True]
# 478 Text feature [cell] present in test data point [True]
# 479 Text feature [www] present in test data point [True]
# 481 Text feature [key] present in test data point [True]
# 484 Text feature [damage] present in test data point [True]
# 485 Text feature [right] present in test data point [True]
# 487 Text feature [possible] present in test data point [True]
# 488 Text feature [sequence] present in test data point [True]
# 490 Text feature [type] present in test data point [True]
# 491 Text feature [values] present in test data point [True]
# 492 Text feature [extracellular] present in test data point [True]
# 493 Text feature [among] present in test data point [True]
# 494 Text feature [another] present in test data point [True]
# 497 Text feature [might] present in test data point [True]
# 498 Text feature [biological] present in test data point [True]
# 499 Text feature [structures] present in test data point [True]
# Out of the top  500  features  152 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42,n_jobs=-1)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42,n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1891975378635273
# for alpha = 1e-05
# Log Loss : 1.1669071868909806
# for alpha = 0.0001
# Log Loss : 1.0781242458727613
# for alpha = 0.001
# Log Loss : 1.1541115218606726
# for alpha = 0.01
# Log Loss : 1.4054736176680571
# for alpha = 0.1
# Log Loss : 1.6778196075403145
# for alpha = 1
# Log Loss : 1.7607951491053861
# For values of best alpha =  0.0001 The train log loss is: 0.43568105577083244
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0781242458727613
# For values of best alpha =  0.0001 The test log loss is: 1.0326816326529882

# %% [markdown]
# **We have achieved log loss less than 1.0 even without class balancing**

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0781242458727613
# Number of mis-classified points : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0647 0.0778 0.009  0.5338 0.1828 0.1108 0.0146 0.0039 0.0026]]
# Actual Class : 4
# --------------------------------------------------
# 21 Text feature [suppressor] present in test data point [True]
# 116 Text feature [lane] present in test data point [True]
# 147 Text feature [missense] present in test data point [True]
# 159 Text feature [tagged] present in test data point [True]
# 164 Text feature [tumorigenesis] present in test data point [True]
# 167 Text feature [dominant] present in test data point [True]
# 194 Text feature [family] present in test data point [True]
# 210 Text feature [caused] present in test data point [True]
# 228 Text feature [substrate] present in test data point [True]
# 229 Text feature [bind] present in test data point [True]
# 241 Text feature [intermediate] present in test data point [True]
# 251 Text feature [cycle] present in test data point [True]
# 255 Text feature [washed] present in test data point [True]
# 256 Text feature [mm] present in test data point [True]
# 267 Text feature [protein] present in test data point [True]
# 270 Text feature [transfected] present in test data point [True]
# 271 Text feature [show] present in test data point [True]
# 301 Text feature [germline] present in test data point [True]
# 307 Text feature [free] present in test data point [True]
# 312 Text feature [ca] present in test data point [True]
# 313 Text feature [consequences] present in test data point [True]
# 325 Text feature [changes] present in test data point [True]
# 330 Text feature [relatively] present in test data point [True]
# 332 Text feature [reduced] present in test data point [True]
# 336 Text feature [via] present in test data point [True]
# 340 Text feature [degradation] present in test data point [True]
# 348 Text feature [years] present in test data point [True]
# 352 Text feature [52] present in test data point [True]
# 362 Text feature [affected] present in test data point [True]
# 363 Text feature [catalytic] present in test data point [True]
# 370 Text feature [bound] present in test data point [True]
# 371 Text feature [tyrosine] present in test data point [True]
# 375 Text feature [several] present in test data point [True]
# 378 Text feature [specifically] present in test data point [True]
# 381 Text feature [led] present in test data point [True]
# 389 Text feature [anti] present in test data point [True]
# 391 Text feature [see] present in test data point [True]
# 393 Text feature [heterozygous] present in test data point [True]
# 402 Text feature [high] present in test data point [True]
# 410 Text feature [due] present in test data point [True]
# 416 Text feature [seen] present in test data point [True]
# 426 Text feature [mouse] present in test data point [True]
# 427 Text feature [buffer] present in test data point [True]
# 428 Text feature [play] present in test data point [True]
# 433 Text feature [activity] present in test data point [True]
# 438 Text feature [2a] present in test data point [True]
# 448 Text feature [dna] present in test data point [True]
# 451 Text feature [shows] present in test data point [True]
# 453 Text feature [indeed] present in test data point [True]
# 459 Text feature [mutants] present in test data point [True]
# 461 Text feature [functional] present in test data point [True]
# 469 Text feature [plasmid] present in test data point [True]
# 470 Text feature [considered] present in test data point [True]
# 471 Text feature [conserved] present in test data point [True]
# 474 Text feature [cbl] present in test data point [True]
# 476 Text feature [29] present in test data point [True]
# 481 Text feature [page] present in test data point [True]
# 484 Text feature [transfection] present in test data point [True]
# 487 Text feature [described] present in test data point [True]
# 496 Text feature [loss] present in test data point [True]
# Out of the top  500  features  60 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 600
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[5.651e-01 1.040e-02 3.000e-03 3.950e-01 6.800e-03 4.500e-03 4.900e-03
#   1.020e-02 1.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 15 Text feature [hotspots] present in test data point [True]
# 37 Text feature [surface] present in test data point [True]
# 51 Text feature [hotspot] present in test data point [True]
# 95 Text feature [nucleus] present in test data point [True]
# 103 Text feature [deficient] present in test data point [True]
# 118 Text feature [hydrophobic] present in test data point [True]
# 136 Text feature [panel] present in test data point [True]
# 144 Text feature [encoding] present in test data point [True]
# 156 Text feature [21] present in test data point [True]
# 158 Text feature [brain] present in test data point [True]
# 162 Text feature [transcriptional] present in test data point [True]
# 185 Text feature [functions] present in test data point [True]
# 186 Text feature [ability] present in test data point [True]
# 199 Text feature [loss] present in test data point [True]
# 201 Text feature [rather] present in test data point [True]
# 222 Text feature [fraction] present in test data point [True]
# 228 Text feature [position] present in test data point [True]
# 241 Text feature [molecules] present in test data point [True]
# 250 Text feature [function] present in test data point [True]
# 254 Text feature [calculated] present in test data point [True]
# 255 Text feature [next] present in test data point [True]
# 262 Text feature [identify] present in test data point [True]
# 266 Text feature [mutational] present in test data point [True]
# 268 Text feature [side] present in test data point [True]
# 270 Text feature [deletion] present in test data point [True]
# 271 Text feature [defined] present in test data point [True]
# 279 Text feature [percentage] present in test data point [True]
# 280 Text feature [displayed] present in test data point [True]
# 282 Text feature [affect] present in test data point [True]
# 283 Text feature [value] present in test data point [True]
# 285 Text feature [subjected] present in test data point [True]
# 289 Text feature [remaining] present in test data point [True]
# 294 Text feature [structure] present in test data point [True]
# 296 Text feature [peptide] present in test data point [True]
# 305 Text feature [upon] present in test data point [True]
# 311 Text feature [moreover] present in test data point [True]
# 316 Text feature [driven] present in test data point [True]
# 320 Text feature [specificity] present in test data point [True]
# 322 Text feature [general] present in test data point [True]
# 326 Text feature [nuclear] present in test data point [True]
# 330 Text feature [vivo] present in test data point [True]
# 335 Text feature [construct] present in test data point [True]
# 336 Text feature [individual] present in test data point [True]
# 337 Text feature [ref] present in test data point [True]
# 341 Text feature [chain] present in test data point [True]
# 342 Text feature [signal] present in test data point [True]
# 344 Text feature [therefore] present in test data point [True]
# 345 Text feature [hydrogen] present in test data point [True]
# 347 Text feature [less] present in test data point [True]
# 348 Text feature [carrying] present in test data point [True]
# 349 Text feature [activities] present in test data point [True]
# 350 Text feature [1997] present in test data point [True]
# 352 Text feature [staining] present in test data point [True]
# 353 Text feature [normalized] present in test data point [True]
# 355 Text feature [somatic] present in test data point [True]
# 356 Text feature [region] present in test data point [True]
# 358 Text feature [page] present in test data point [True]
# 360 Text feature [impact] present in test data point [True]
# 364 Text feature [complexes] present in test data point [True]
# 365 Text feature [strong] present in test data point [True]
# 366 Text feature [controls] present in test data point [True]
# 367 Text feature [crystal] present in test data point [True]
# 369 Text feature [strand] present in test data point [True]
# 370 Text feature [population] present in test data point [True]
# 371 Text feature [targeting] present in test data point [True]
# 372 Text feature [responses] present in test data point [True]
# 373 Text feature [treated] present in test data point [True]
# 374 Text feature [vitro] present in test data point [True]
# 376 Text feature [essential] present in test data point [True]
# 378 Text feature [early] present in test data point [True]
# 379 Text feature [s1] present in test data point [True]
# 382 Text feature [transcription] present in test data point [True]
# 383 Text feature [dependent] present in test data point [True]
# 385 Text feature [positions] present in test data point [True]
# 386 Text feature [assess] present in test data point [True]
# 387 Text feature [complex] present in test data point [True]
# 388 Text feature [rt] present in test data point [True]
# 390 Text feature [1999] present in test data point [True]
# 391 Text feature [greater] present in test data point [True]
# 392 Text feature [sequenced] present in test data point [True]
# 393 Text feature [impaired] present in test data point [True]
# 394 Text feature [sequencing] present in test data point [True]
# 396 Text feature [structural] present in test data point [True]
# 397 Text feature [nucleotide] present in test data point [True]
# 398 Text feature [defects] present in test data point [True]
# 399 Text feature [line] present in test data point [True]
# 400 Text feature [established] present in test data point [True]
# 403 Text feature [assays] present in test data point [True]
# 404 Text feature [1b] present in test data point [True]
# 405 Text feature [regulatory] present in test data point [True]
# 406 Text feature [allele] present in test data point [True]
# 410 Text feature [sequences] present in test data point [True]
# 411 Text feature [17] present in test data point [True]
# 414 Text feature [indicated] present in test data point [True]
# 415 Text feature [values] present in test data point [True]
# 416 Text feature [37] present in test data point [True]
# 418 Text feature [molecule] present in test data point [True]
# 419 Text feature [screening] present in test data point [True]
# 420 Text feature [whole] present in test data point [True]
# 421 Text feature [sirna] present in test data point [True]
# 423 Text feature [author] present in test data point [True]
# 424 Text feature [induce] present in test data point [True]
# 425 Text feature [length] present in test data point [True]
# 426 Text feature [complete] present in test data point [True]
# 427 Text feature [possibility] present in test data point [True]
# 429 Text feature [resulted] present in test data point [True]
# 430 Text feature [suppression] present in test data point [True]
# 431 Text feature [fold] present in test data point [True]
# 432 Text feature [cell] present in test data point [True]
# 433 Text feature [colorectal] present in test data point [True]
# 434 Text feature [frequency] present in test data point [True]
# 435 Text feature [www] present in test data point [True]
# 436 Text feature [sensitivity] present in test data point [True]
# 437 Text feature [cohort] present in test data point [True]
# 440 Text feature [http] present in test data point [True]
# 442 Text feature [reduction] present in test data point [True]
# 443 Text feature [interestingly] present in test data point [True]
# 444 Text feature [one] present in test data point [True]
# 445 Text feature [corresponding] present in test data point [True]
# 447 Text feature [core] present in test data point [True]
# 449 Text feature [blood] present in test data point [True]
# 450 Text feature [sds] present in test data point [True]
# 451 Text feature [human] present in test data point [True]
# 453 Text feature [knockdown] present in test data point [True]
# 454 Text feature [key] present in test data point [True]
# 455 Text feature [following] present in test data point [True]
# 457 Text feature [another] present in test data point [True]
# 458 Text feature [melanoma] present in test data point [True]
# 459 Text feature [reporter] present in test data point [True]
# 460 Text feature [primers] present in test data point [True]
# 462 Text feature [powerpoint] present in test data point [True]
# 465 Text feature [protein] present in test data point [True]
# 467 Text feature [assessed] present in test data point [True]
# 468 Text feature [49] present in test data point [True]
# 470 Text feature [36] present in test data point [True]
# 471 Text feature [located] present in test data point [True]
# 472 Text feature [change] present in test data point [True]
# 473 Text feature [might] present in test data point [True]
# 474 Text feature [end] present in test data point [True]
# 475 Text feature [previous] present in test data point [True]
# 477 Text feature [additional] present in test data point [True]
# 478 Text feature [sequence] present in test data point [True]
# 479 Text feature [major] present in test data point [True]
# 480 Text feature [cause] present in test data point [True]
# 481 Text feature [affecting] present in test data point [True]
# 482 Text feature [domains] present in test data point [True]
# 484 Text feature [furthermore] present in test data point [True]
# 485 Text feature [manufacturer] present in test data point [True]
# 486 Text feature [42] present in test data point [True]
# 487 Text feature [types] present in test data point [True]
# 490 Text feature [context] present in test data point [True]
# 492 Text feature [type] present in test data point [True]
# 493 Text feature [possible] present in test data point [True]
# 495 Text feature [stability] present in test data point [True]
# 496 Text feature [medium] present in test data point [True]
# 497 Text feature [despite] present in test data point [True]
# 498 Text feature [among] present in test data point [True]
# Out of the top  500  features  157 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42,n_jobs=-1)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1339279405748974
# for C = 0.0001
# Log Loss : 1.084027493701894
# for C = 0.001
# Log Loss : 1.1250762674333665
# for C = 0.01
# Log Loss : 1.3995261127741858
# for C = 0.1
# Log Loss : 1.7170445696257985
# for C = 1
# Log Loss : 1.8008540166787401
# for C = 10
# Log Loss : 1.8008541968170646
# for C = 100
# Log Loss : 1.8008540616715776
# For values of best alpha =  0.0001 The train log loss is: 0.47792992435070525
# For values of best alpha =  0.0001 The cross validation log loss is: 1.084027493701894
# For values of best alpha =  0.0001 The test log loss is: 1.0433396458049438

# %% [markdown]
# **We got 0.988 log loss with linear SVM also using TfidfVectorizer**

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.084027493701894
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.06   0.0994 0.0121 0.3739 0.2879 0.1383 0.0189 0.0051 0.0043]]
# Actual Class : 4
# --------------------------------------------------
# 61 Text feature [suppressor] present in test data point [True]
# 197 Text feature [missense] present in test data point [True]
# 198 Text feature [lane] present in test data point [True]
# 199 Text feature [bind] present in test data point [True]
# 200 Text feature [caused] present in test data point [True]
# 201 Text feature [seen] present in test data point [True]
# 202 Text feature [tumorigenesis] present in test data point [True]
# 203 Text feature [free] present in test data point [True]
# 211 Text feature [dominant] present in test data point [True]
# 216 Text feature [consequences] present in test data point [True]
# 217 Text feature [substrate] present in test data point [True]
# 218 Text feature [52] present in test data point [True]
# 222 Text feature [via] present in test data point [True]
# 223 Text feature [mouse] present in test data point [True]
# 225 Text feature [tagged] present in test data point [True]
# 226 Text feature [due] present in test data point [True]
# 227 Text feature [show] present in test data point [True]
# 230 Text feature [intermediate] present in test data point [True]
# 232 Text feature [changes] present in test data point [True]
# 233 Text feature [tyrosine] present in test data point [True]
# 235 Text feature [see] present in test data point [True]
# 237 Text feature [cycle] present in test data point [True]
# 238 Text feature [3b] present in test data point [True]
# 240 Text feature [degradation] present in test data point [True]
# 243 Text feature [years] present in test data point [True]
# 245 Text feature [family] present in test data point [True]
# 249 Text feature [enhanced] present in test data point [True]
# 251 Text feature [led] present in test data point [True]
# 252 Text feature [bound] present in test data point [True]
# 256 Text feature [relatively] present in test data point [True]
# 259 Text feature [transfected] present in test data point [True]
# 450 Text feature [reduced] present in test data point [True]
# 451 Text feature [protein] present in test data point [True]
# 455 Text feature [mutants] present in test data point [True]
# 459 Text feature [shows] present in test data point [True]
# 460 Text feature [high] present in test data point [True]
# 462 Text feature [dna] present in test data point [True]
# 466 Text feature [mm] present in test data point [True]
# 467 Text feature [transfection] present in test data point [True]
# 468 Text feature [indeed] present in test data point [True]
# 469 Text feature [heterozygous] present in test data point [True]
# 472 Text feature [washed] present in test data point [True]
# 476 Text feature [anti] present in test data point [True]
# 480 Text feature [specifically] present in test data point [True]
# 481 Text feature [thus] present in test data point [True]
# 485 Text feature [several] present in test data point [True]
# 487 Text feature [considered] present in test data point [True]
# 490 Text feature [buffer] present in test data point [True]
# 491 Text feature [genome] present in test data point [True]
# 493 Text feature [29] present in test data point [True]
# 495 Text feature [developed] present in test data point [True]
# 496 Text feature [2a] present in test data point [True]
# 498 Text feature [model] present in test data point [True]
# Out of the top  500  features  53 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 600
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.541  0.0351 0.0028 0.3596 0.0167 0.0103 0.0265 0.0055 0.0025]]
# Actual Class : 4
# --------------------------------------------------
# 65 Text feature [hotspots] present in test data point [True]
# 66 Text feature [surface] present in test data point [True]
# 67 Text feature [21] present in test data point [True]
# 68 Text feature [hotspot] present in test data point [True]
# 208 Text feature [encoding] present in test data point [True]
# 210 Text feature [panel] present in test data point [True]
# 211 Text feature [rather] present in test data point [True]
# 212 Text feature [ability] present in test data point [True]
# 213 Text feature [functions] present in test data point [True]
# 214 Text feature [loss] present in test data point [True]
# 215 Text feature [nucleus] present in test data point [True]
# 216 Text feature [deficient] present in test data point [True]
# 217 Text feature [hydrophobic] present in test data point [True]
# 219 Text feature [brain] present in test data point [True]
# 220 Text feature [identify] present in test data point [True]
# 223 Text feature [transcriptional] present in test data point [True]
# 224 Text feature [position] present in test data point [True]
# 225 Text feature [1997] present in test data point [True]
# 227 Text feature [staining] present in test data point [True]
# 228 Text feature [upon] present in test data point [True]
# 229 Text feature [subjected] present in test data point [True]
# 230 Text feature [activities] present in test data point [True]
# 231 Text feature [driven] present in test data point [True]
# 234 Text feature [despite] present in test data point [True]
# 235 Text feature [percentage] present in test data point [True]
# 236 Text feature [impaired] present in test data point [True]
# 238 Text feature [strong] present in test data point [True]
# 239 Text feature [remaining] present in test data point [True]
# 240 Text feature [next] present in test data point [True]
# 242 Text feature [somatic] present in test data point [True]
# 243 Text feature [vivo] present in test data point [True]
# 244 Text feature [defined] present in test data point [True]
# 246 Text feature [chain] present in test data point [True]
# 247 Text feature [treated] present in test data point [True]
# 249 Text feature [calculated] present in test data point [True]
# 250 Text feature [moreover] present in test data point [True]
# 252 Text feature [dependent] present in test data point [True]
# 253 Text feature [frequency] present in test data point [True]
# 356 Text feature [targeting] present in test data point [True]
# 357 Text feature [side] present in test data point [True]
# 358 Text feature [values] present in test data point [True]
# 359 Text feature [function] present in test data point [True]
# 361 Text feature [fraction] present in test data point [True]
# 362 Text feature [responses] present in test data point [True]
# 363 Text feature [lysates] present in test data point [True]
# 364 Text feature [regulatory] present in test data point [True]
# 365 Text feature [sequenced] present in test data point [True]
# 366 Text feature [impact] present in test data point [True]
# 367 Text feature [resulted] present in test data point [True]
# 369 Text feature [general] present in test data point [True]
# 370 Text feature [mutational] present in test data point [True]
# 371 Text feature [molecules] present in test data point [True]
# 372 Text feature [carrying] present in test data point [True]
# 373 Text feature [sensitivity] present in test data point [True]
# 374 Text feature [construct] present in test data point [True]
# 375 Text feature [complexes] present in test data point [True]
# 376 Text feature [signal] present in test data point [True]
# 377 Text feature [defects] present in test data point [True]
# 378 Text feature [established] present in test data point [True]
# 379 Text feature [rt] present in test data point [True]
# 380 Text feature [line] present in test data point [True]
# 383 Text feature [vitro] present in test data point [True]
# 384 Text feature [less] present in test data point [True]
# 385 Text feature [structure] present in test data point [True]
# 386 Text feature [ref] present in test data point [True]
# 387 Text feature [possibility] present in test data point [True]
# 388 Text feature [directed] present in test data point [True]
# 389 Text feature [powerpoint] present in test data point [True]
# 390 Text feature [strand] present in test data point [True]
# 391 Text feature [deletion] present in test data point [True]
# 392 Text feature [fold] present in test data point [True]
# 393 Text feature [assessed] present in test data point [True]
# 394 Text feature [might] present in test data point [True]
# 395 Text feature [sequencing] present in test data point [True]
# 396 Text feature [normalized] present in test data point [True]
# 397 Text feature [lines] present in test data point [True]
# 398 Text feature [observations] present in test data point [True]
# 399 Text feature [19] present in test data point [True]
# 400 Text feature [antibodies] present in test data point [True]
# 401 Text feature [37] present in test data point [True]
# 402 Text feature [affect] present in test data point [True]
# 403 Text feature [27] present in test data point [True]
# 404 Text feature [reporter] present in test data point [True]
# 405 Text feature [like] present in test data point [True]
# 406 Text feature [knockdown] present in test data point [True]
# 407 Text feature [17] present in test data point [True]
# 408 Text feature [table] present in test data point [True]
# 409 Text feature [yet] present in test data point [True]
# 410 Text feature [screening] present in test data point [True]
# 411 Text feature [cell] present in test data point [True]
# 412 Text feature [s1] present in test data point [True]
# 413 Text feature [reduced] present in test data point [True]
# 414 Text feature [de] present in test data point [True]
# 415 Text feature [complex] present in test data point [True]
# 416 Text feature [controls] present in test data point [True]
# 417 Text feature [patients] present in test data point [True]
# 419 Text feature [type] present in test data point [True]
# 420 Text feature [induce] present in test data point [True]
# 421 Text feature [nucleotide] present in test data point [True]
# 422 Text feature [greater] present in test data point [True]
# 423 Text feature [13] present in test data point [True]
# 424 Text feature [available] present in test data point [True]
# 426 Text feature [population] present in test data point [True]
# 428 Text feature [displayed] present in test data point [True]
# 429 Text feature [signalling] present in test data point [True]
# 430 Text feature [assess] present in test data point [True]
# 431 Text feature [positions] present in test data point [True]
# 432 Text feature [specificity] present in test data point [True]
# 433 Text feature [therefore] present in test data point [True]
# 434 Text feature [cohort] present in test data point [True]
# 435 Text feature [colorectal] present in test data point [True]
# 436 Text feature [negative] present in test data point [True]
# 437 Text feature [reduction] present in test data point [True]
# 438 Text feature [www] present in test data point [True]
# 440 Text feature [essential] present in test data point [True]
# 441 Text feature [analyzed] present in test data point [True]
# 442 Text feature [proliferation] present in test data point [True]
# 443 Text feature [indicated] present in test data point [True]
# 444 Text feature [page] present in test data point [True]
# 445 Text feature [note] present in test data point [True]
# 446 Text feature [major] present in test data point [True]
# 447 Text feature [peptide] present in test data point [True]
# 448 Text feature [32] present in test data point [True]
# 449 Text feature [human] present in test data point [True]
# 452 Text feature [melanoma] present in test data point [True]
# 453 Text feature [assays] present in test data point [True]
# 454 Text feature [added] present in test data point [True]
# 455 Text feature [harboring] present in test data point [True]
# 456 Text feature [gfp] present in test data point [True]
# 457 Text feature [medium] present in test data point [True]
# 458 Text feature [showing] present in test data point [True]
# 459 Text feature [value] present in test data point [True]
# 460 Text feature [protein] present in test data point [True]
# 461 Text feature [obtained] present in test data point [True]
# 462 Text feature [ha] present in test data point [True]
# 463 Text feature [wild] present in test data point [True]
# 464 Text feature [length] present in test data point [True]
# 465 Text feature [confirmed] present in test data point [True]
# 466 Text feature [1b] present in test data point [True]
# 467 Text feature [recently] present in test data point [True]
# 468 Text feature [complete] present in test data point [True]
# 469 Text feature [sequences] present in test data point [True]
# 470 Text feature [status] present in test data point [True]
# 471 Text feature [sirna] present in test data point [True]
# 472 Text feature [patient] present in test data point [True]
# 473 Text feature [determined] present in test data point [True]
# 474 Text feature [36] present in test data point [True]
# 475 Text feature [interestingly] present in test data point [True]
# 477 Text feature [alterations] present in test data point [True]
# 478 Text feature [nuclear] present in test data point [True]
# 479 Text feature [sequence] present in test data point [True]
# 480 Text feature [partial] present in test data point [True]
# 481 Text feature [among] present in test data point [True]
# 482 Text feature [majority] present in test data point [True]
# 483 Text feature [average] present in test data point [True]
# 484 Text feature [allele] present in test data point [True]
# 485 Text feature [affecting] present in test data point [True]
# 486 Text feature [proteins] present in test data point [True]
# 487 Text feature [appears] present in test data point [True]
# 488 Text feature [blood] present in test data point [True]
# 490 Text feature [sds] present in test data point [True]
# 492 Text feature [analyses] present in test data point [True]
# 493 Text feature [metastatic] present in test data point [True]
# 494 Text feature [key] present in test data point [True]
# 495 Text feature [42] present in test data point [True]
# 498 Text feature [56] present in test data point [True]
# 499 Text feature [presence] present in test data point [True]
# Out of the top  500  features  167 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,1500,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.228669352008894
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2518162970196418
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2123750274950849
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.246096628005634
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2094635501103002
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2425640565109712
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2065059480730103
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2397384114788992
# for n_estimators = 1500 and max depth =  5
# Log Loss : 1.2048465735864105
# for n_estimators = 1500 and max depth =  10
# Log Loss : 1.239912429605884
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2044671973374546
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2401790470017748
# For values of best estimator =  2000 The train log loss is: 0.8553133788658391
# For values of best estimator =  2000 The cross validation log loss is: 1.2044671973374546
# For values of best estimator =  2000 The test log loss is: 1.2173214629805473

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.2044671973374546
# Number of mis-classified points : 0.43045112781954886
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2203 0.0678 0.0204 0.389  0.0887 0.0711 0.1276 0.0072 0.0078]]
# Actual Class : 4
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 2 Text feature [activated] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [suppressor] present in test data point [True]
# 6 Text feature [phosphorylation] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 10 Text feature [inhibitors] present in test data point [True]
# 11 Text feature [receptor] present in test data point [True]
# 12 Text feature [oncogenic] present in test data point [True]
# 13 Text feature [missense] present in test data point [True]
# 15 Text feature [loss] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 22 Text feature [signaling] present in test data point [True]
# 24 Text feature [stability] present in test data point [True]
# 25 Text feature [functional] present in test data point [True]
# 28 Text feature [classified] present in test data point [True]
# 31 Text feature [variants] present in test data point [True]
# 37 Text feature [proteins] present in test data point [True]
# 39 Text feature [neutral] present in test data point [True]
# 40 Text feature [growth] present in test data point [True]
# 42 Text feature [treated] present in test data point [True]
# 45 Text feature [functions] present in test data point [True]
# 46 Text feature [expression] present in test data point [True]
# 47 Text feature [cells] present in test data point [True]
# 49 Text feature [drug] present in test data point [True]
# 50 Text feature [kinases] present in test data point [True]
# 52 Text feature [cell] present in test data point [True]
# 60 Text feature [downstream] present in test data point [True]
# 61 Text feature [oncogene] present in test data point [True]
# 67 Text feature [patients] present in test data point [True]
# 69 Text feature [ring] present in test data point [True]
# 72 Text feature [use] present in test data point [True]
# 81 Text feature [activity] present in test data point [True]
# 84 Text feature [predicted] present in test data point [True]
# 85 Text feature [lines] present in test data point [True]
# 86 Text feature [tagged] present in test data point [True]
# 87 Text feature [phosphorylated] present in test data point [True]
# 89 Text feature [egfr] present in test data point [True]
# 90 Text feature [assays] present in test data point [True]
# 94 Text feature [activate] present in test data point [True]
# 99 Text feature [sequence] present in test data point [True]
# Out of the top  100  features  42 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 10
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.3551 0.0241 0.0111 0.4687 0.0539 0.0458 0.0284 0.0048 0.0081]]
# Actuall Class : 1
# --------------------------------------------------
# 5 Text feature [suppressor] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 15 Text feature [loss] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 31 Text feature [variants] present in test data point [True]
# 37 Text feature [proteins] present in test data point [True]
# 40 Text feature [growth] present in test data point [True]
# 41 Text feature [yeast] present in test data point [True]
# 46 Text feature [expression] present in test data point [True]
# 47 Text feature [cells] present in test data point [True]
# 52 Text feature [cell] present in test data point [True]
# 76 Text feature [variant] present in test data point [True]
# 81 Text feature [activity] present in test data point [True]
# 90 Text feature [assays] present in test data point [True]
# 93 Text feature [response] present in test data point [True]
# 99 Text feature [sequence] present in test data point [True]
# Out of the top  100  features  16 are present in query point

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.0002, penalty='l2', loss='log', class_weight='balanced', random_state=0,n_jobs=-1)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=0.0001, penalty='l2', loss='hinge', class_weight='balanced', random_state=0,n_jobs=-1)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=1000)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.06
# Support vector machines : Log Loss: 1.10
# Naive Bayes : Log Loss: 1.49
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.174
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.996
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.417
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.127
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.350
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.859

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.4495095049778528
# Log loss (CV) on the stacking classifier : 1.127018820538494
# Log loss (test) on the stacking classifier : 1.1028156780762755
# Number of missclassified point : 0.3518796992481203
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.6489290238005883
# Log loss (CV) on the VotingClassifier : 1.1159797014591888
# Log loss (test) on the VotingClassifier : 1.0623914218243944
# Number of missclassified point : 0.3548872180451128
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# **Summary for TfidfVectorizer with top 1000 words using idf score**

# %%
from prettytable import PrettyTable
    
x = PrettyTable()

x.field_names = ["Model", "train log loss", "CV log loss", "Test log loss"]

x.add_row(["Naive Bayes Classifier", 0.504, 1.217, 1.206])
x.add_row(["KNN classifier", 0.810, 1.126, 1.076])
x.add_row(["LR with class balancing", 0.500, 1.050, 1.007])
x.add_row(["LR with no class balancing", 0.435, 1.078, 1.032])
x.add_row(["Linear SVM classifier", 0.477, 1.084, 1.043])
x.add_row(["Random Forest Classifier", 0.855, 1.204, 1.217])
x.add_row(["Stacking Classifier", 0.449, 1.127, 1.102])
x.add_row(["Voting Classifier", 0.64, 1.115, 1.06])
print(x)
# Out:
# +----------------------------+----------------+-------------+---------------+
# |           Model            | train log loss | CV log loss | Test log loss |
# +----------------------------+----------------+-------------+---------------+
# |   Naive Bayes Classifier   |     0.504      |    1.217    |     1.206     |
# |       KNN classifier       |      0.81      |    1.126    |     1.076     |
# |  LR with class balancing   |      0.5       |     1.05    |     1.007     |
# | LR with no class balancing |     0.435      |    1.078    |     1.032     |
# |   Linear SVM classifier    |     0.477      |    1.084    |     1.043     |
# |  Random Forest Classifier  |     0.855      |    1.204    |     1.217     |
# |    Stacking Classifier     |     0.449      |    1.127    |     1.102     |
# |     Voting Classifier      |      0.64      |    1.115    |      1.06     |
# +----------------------------+----------------+-------------+---------------+
